# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Load dataset
df = pd.read_csv('../machine-learning-projects/datasets/credit_card_transactions.csv')
df.head()
# Out:
#    TransactionID  Amount   Time     Location          Merchant  Device  Fraud
# 0              1    12.5  08:30     New York        CoffeeShop  Mobile      0
# 1              2  5000.0  02:15  Los Angeles  ElectronicsStore  Laptop      1
# 2              3    15.0  13:20     New York        CoffeeShop  Mobile      0
# 3              4   200.0  22:45      Chicago       Supermarket     Web      0
# 4              5  4500.0  03:10  Los Angeles  LuxuryWatchStore  Mobile      1

# %%
# Encode categorical columns
le_location = LabelEncoder()
df['Location'] = le_location.fit_transform(df['Location'])

le_merchant = LabelEncoder()
df['Merchant'] = le_merchant.fit_transform(df['Merchant'])

le_device = LabelEncoder()
df['Device'] = le_device.fit_transform(df['Device'])

# Convert 'Time' to numeric features (hour + minute)
df['Hour'] = df['Time'].str.split(':').str[0].astype(int)
df['Minute'] = df['Time'].str.split(':').str[1].astype(int)
df.drop('Time', axis=1, inplace=True)

# %%
df.head()
# Out:
#    TransactionID  Amount  Location  Merchant  Device  Fraud  Hour  Minute
# 0              1    12.5         4         3       1      0     8      30
# 1              2  5000.0         2         4       0      1     2      15
# 2              3    15.0         4         3       1      0    13      20
# 3              4   200.0         1        11       2      0    22      45
# 4              5  4500.0         2         9       1      1     3      10

# %%
# Features and target
X = df.drop(['TransactionID', 'Fraud'], axis=1)
y = df['Fraud']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predict on test set
y_pred = rf.predict(X_test)

# Evaluate
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
